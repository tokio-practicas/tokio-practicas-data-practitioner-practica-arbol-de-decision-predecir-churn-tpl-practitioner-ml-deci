# %% [markdown]
# # Práctica: Modelo de Árbol de Decisión para Predecir Churn
#
# Completa cada sección siguiendo las instrucciones. No modifiques las celdas de markdown.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Carga de datos
#
# Lee el archivo `../data/telecom_churn.csv` con pandas. Muestra las primeras filas.

# %%
# Tu código aquí

# %% [markdown]
# ## 2. Exploración rápida
#
# Responde con código:
# - ¿Cuántas filas y columnas tiene el dataset?
# - ¿Qué tipos de datos hay?
# - ¿Hay valores nulos?
# - ¿Cuál es la distribución del target (`churn`)? ¿Está balanceado?

# %%
# Tu código aquí

# %% [markdown]
# ## 3. Preparación de datos
#
# - Codifica las variables categóricas (puedes usar `pd.get_dummies()` o `LabelEncoder`)
# - Separa features (X) y target (y)
# - Haz train/test split: 80% train, 20% test, `random_state=42`

# %%
# Tu código aquí

# %% [markdown]
# ## 4. Entrenamiento del modelo
#
# Entrena un `DecisionTreeClassifier` con `random_state=42`. Haz `.fit()` con los datos de train.

# %%
# Tu código aquí

# %% [markdown]
# ## 5. Evaluación
#
# Calcula sobre el set de **test**:
# - **Accuracy**: proporción de predicciones correctas
# - **Precision**: de los que predijo como churn, ¿cuántos lo son?
# - **Recall**: de los que realmente hicieron churn, ¿cuántos detectó?
# - Muestra la **confusion matrix** con `ConfusionMatrixDisplay`

# %%
# Tu código aquí

# %% [markdown]
# ## 6. Top 3 features más importantes
#
# Usa `model.feature_importances_` para identificar las 3 variables que más pesan en la decisión.
# - Haz un gráfico de barras horizontal con las importancias
# - En una celda markdown debajo, explica: ¿tiene sentido que estas sean las más importantes? ¿Por qué?

# %%
# Tu código aquí

# %% [markdown]
# ### Explicación de las top 3 features
#
# *Escribe tu explicación aquí...*

# %% [markdown]
# ## 7. Conclusiones
#
# Responde en markdown:
# - ¿El modelo es suficientemente bueno para usarlo en producción? ¿Por qué?
# - ¿Qué recomendarías al equipo de retención basándote en los resultados?
# - ¿Qué mejorarías si tuvieras más tiempo?

# %% [markdown]
# *Escribe tus conclusiones aquí...*
